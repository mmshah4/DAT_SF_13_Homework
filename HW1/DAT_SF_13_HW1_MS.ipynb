# %%
# Titanic Homework - 1
# Import packges - Numpy, Seaborn, Pandas and Matplot
# import seaborn as sns (count not import Seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#Floats only show two digits for display
pd.set_option('display.precision', 2)

# %%
# Read the Titanic dataset from the local directory
# %ls
# %cd Documents/General_Assembley/DAT_SF_13/homework
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BCB8-D3BA
#
#  Directory of C:\Users\Disha
#
# 03/11/2015  07:31 PM    <DIR>          .
# 03/11/2015  07:31 PM    <DIR>          ..
# 03/06/2015  11:07 PM    <DIR>          .continuum
# 03/11/2015  07:31 PM                54 .gitconfig
# 03/06/2015  11:12 PM    <DIR>          .ipython
# 03/15/2015  09:27 PM    <DIR>          .matplotlib
# 03/09/2015  09:01 PM    <DIR>          .ssh
# 11/20/2014  10:45 PM    <DIR>          .VirtualBox
# 03/15/2015  08:43 PM    <DIR>          Anaconda
# 03/13/2015  10:24 PM    <DIR>          Contacts
# 03/13/2015  10:24 PM    <DIR>          Desktop
# 03/13/2015  10:24 PM    <DIR>          Documents
# 03/13/2015  11:03 PM    <DIR>          Downloads
# 03/06/2015  11:19 PM    <DIR>          envs
# 03/13/2015  10:24 PM    <DIR>          Favorites
# 03/13/2015  10:24 PM    <DIR>          Links
# 03/13/2015  10:24 PM    <DIR>          Music
# 03/13/2015  10:24 PM    <DIR>          Pictures
# ...

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BCB8-D3BA
#
#  Directory of C:\Users\Disha\Documents\General_Assembley\DAT_SF_13\homework
#
# 03/15/2015  09:02 PM    <DIR>          .
# 03/15/2015  09:02 PM    <DIR>          ..
# 03/15/2015  09:02 PM            76,825 DAT13_HW1_assignment.pdf
# 03/15/2015  09:02 PM            60,301 titanic.csv
#                2 File(s)        137,126 bytes
#                2 Dir(s)  354,691,497,984 bytes free

# %%
titanic_data2 = pd.read_csv("titanic.csv")

# %%
type(titanic_data2)
titanic_data2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket  Fare Cabin Embarked
# 0      0         A/5 21171   7.2   NaN        S
# 1      0          PC 17599  71.3   C85        C
# 2      0  STON/O2. 3101282   7.9   NaN        S
# 3      0            113803  53.1  C123        S
# 4      0            373450   8.1   NaN        S

# %%
#titanic_data2['Survived'].value_counts()
#titanic_data2['Pclass'].value_counts()
#titanic_data2['Sex'].value_counts()
titanic_data2['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %%
titanic_data2.describe()
# Out:
#        PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# count        891.0     891.0   891.0  714.0  891.0  891.0  891.0
# mean         446.0       0.4     2.3   29.7    0.5    0.4   32.2
# std          257.4       0.5     0.8   14.5    1.1    0.8   49.7
# min            1.0       0.0     1.0    0.4    0.0    0.0    0.0
# 25%          223.5       0.0     2.0   20.1    0.0    0.0    7.9
# 50%          446.0       0.0     3.0   28.0    0.0    0.0   14.5
# 75%          668.5       1.0     3.0   38.0    1.0    0.0   31.0
# max          891.0       1.0     3.0   80.0    8.0    6.0  512.3

# %% [markdown]
# #

# %%
#Q1: There are 891 passengers in the Titanic
#Q2: Overall Survival rate is 40%#
#nan_sex = np.isnan(titanic_data2.Sex)
titanic_data2['Sex'].value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
#Q3: There are 577 male passengers onboard
#Q4: There are 314 female passengers onboard
SurvRate_Sex = titanic_data2.pivot_table('Survived', index='Sex', aggfunc='mean')
print SurvRate_Sex
# Out:
# Sex
# female    0.7
# male      0.2
# Name: Survived, dtype: float64

# %%
type(SurvRate_Sex)
# Out:
# pandas.core.series.Series

# %%
#Q5 and Q6: Survival rate of male and female passenger is 20% and 70% respectively
titanic_data2.Age.describe()
# Out:
# count    714.0
# mean      29.7
# std       14.5
# min        0.4
# 25%       20.1
# 50%       28.0
# 75%       38.0
# max       80.0
# dtype: float64

# %%
#Q7: Average age of all passengers is 29.7
age_nan = np.isnan(titanic_data2.Age)
titanic_data2[age_nan]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
#Replace the missing ages with mean age
mean_age = titanic_data2['Age'].mean()
print mean_age

#titanic_data['age'][nan_ages] = mean_age
#titanic_data.age.describe()
# Out:
# 29.6991176471

# %%
titanic_data2['Age'][age_nan] = mean_age
titanic_data2.Age.describe()
# Out:
# count    891.0
# mean      29.7
# std       13.0
# min        0.4
# 25%       22.0
# 50%       29.7
# 75%       35.0
# max       80.0
# dtype: float64

# %%
age_by_survival = titanic_data2.pivot_table('Age', index = 'Survived', aggfunc = 'mean')
print age_by_survival
# Out:
# Survived
# 0           30.4
# 1           28.5
# Name: Age, dtype: float64

# %%
#Q8 and Q9: Average age of passengers who survived and did not survive are 30.1 years and 28.5 years respectivly

# %%
#Q10: Female have a much higher survival rate
survival_by_service = titanic_data2.pivot_table('Survived', index = 'Pclass', aggfunc = 'mean')
print survival_by_service
# Out:
# Pclass
# 1         0.6
# 2         0.5
# 3         0.2
# Name: Survived, dtype: float64

# %% [markdown]
# #

# %%
#Q11: Survival rate of first, second and third class passenger is 60%, 50% and 20% respectively
#Q12: Female, Higher class and yonger age have a better chance of survival over other groups
#Q13: We should use all of the above features while building model.
